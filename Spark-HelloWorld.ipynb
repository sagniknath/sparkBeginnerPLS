# %%
sc
# Out:
# <SparkContext master=local[2] appName=PySparkShell>

# %%
filePath = "file:///home/snath/spark-ws/AAPL.csv"
apple = sc.textFile(filePath)

# %%
apple
# Out:
# file:///home/snath/spark-ws/AAPL.csv MapPartitionsRDD[7] at textFile at NativeMethodAccessorImpl.java:0

# %%
apple.take(10)
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume',
#  '2018-08-01,199.130005,201.759995,197.309998,201.500000,200.795792,67935700',
#  '2018-08-02,200.580002,208.380005,200.350006,207.389999,206.665207,62404000',
#  '2018-08-03,207.029999,208.740005,205.479996,207.990005,207.263107,33447400',
#  '2018-08-06,208.000000,209.250000,207.070007,209.070007,208.339340,25425400',
#  '2018-08-07,209.320007,209.500000,206.759995,207.110001,206.386185,25587400',
#  '2018-08-08,206.050003,207.809998,204.520004,207.250000,206.525696,22525500',
#  '2018-08-09,207.279999,209.779999,207.199997,208.880005,208.149994,23469200',
#  '2018-08-10,207.360001,209.100006,206.669998,207.529999,207.529999,24611200',
#  '2018-08-13,207.699997,210.949997,207.699997,208.869995,208.869995,25869100']

# %%
apple.count()
# Out:
# 24

# %%
apple.first()
# Out:
# 'Date,Open,High,Low,Close,Adj Close,Volume'

# %%
apple.collect()
# Out:
# ['Date,Open,High,Low,Close,Adj Close,Volume',
#  '2018-08-01,199.130005,201.759995,197.309998,201.500000,200.795792,67935700',
#  '2018-08-02,200.580002,208.380005,200.350006,207.389999,206.665207,62404000',
#  '2018-08-03,207.029999,208.740005,205.479996,207.990005,207.263107,33447400',
#  '2018-08-06,208.000000,209.250000,207.070007,209.070007,208.339340,25425400',
#  '2018-08-07,209.320007,209.500000,206.759995,207.110001,206.386185,25587400',
#  '2018-08-08,206.050003,207.809998,204.520004,207.250000,206.525696,22525500',
#  '2018-08-09,207.279999,209.779999,207.199997,208.880005,208.149994,23469200',
#  '2018-08-10,207.360001,209.100006,206.669998,207.529999,207.529999,24611200',
#  '2018-08-13,207.699997,210.949997,207.699997,208.869995,208.869995,25869100',
#  '2018-08-14,210.160004,210.559998,208.259995,209.750000,209.750000,20748000',
#  '2018-08-15,209.220001,210.740005,208.330002,210.240005,210.240005,28807600',
# ...
